# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshan-Chourasia/Github-repository/blob/main/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

x = np.linspace(0, 10, 100)
y = np.sin(x)
data = np.random.randn(1000)

# 1. Line plot
plt.figure()
plt.plot(x, y)
plt.title('Line Plot')
plt.savefig('line_plot.png')

# %%
plt.figure()
plt.hist(data, bins=30)
plt.title('Histogram')
plt.savefig('histogram.png')

# %%
plt.figure()
plt.scatter(x, y)
plt.title('Scatter Plot')
plt.savefig('scatter_plot.png')

# %%
categories = ['A', 'B', 'C', 'D']
values = [10, 24, 36, 5]
plt.figure()
plt.bar(categories, values)
plt.title('Bar Plot')
plt.savefig('bar_plot.png')

# %%
matrix = np.random.rand(10, 10)
plt.figure()
sns.heatmap(matrix, annot=True, fmt=".1f")
plt.title('Heatmap')
plt.savefig('heatmap.png')

# %%
plt.figure()
sns.boxplot(data=data)
plt.title('Box Plot')
plt.savefig('box_plot.png')
